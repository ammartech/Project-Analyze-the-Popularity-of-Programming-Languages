# %% [markdown]
# <center><img src="prog_lang.jpg" width=500></center>

# %% [markdown]
# How can you determine which programming languages and technologies are most widely used? Which languages are gaining or losing popularity, helping you decide where to focus your efforts?
#
# One excellent data source is Stack Overflow, a programming question-and-answer site with more than 16 million questions on programming topics. Each Stack Overflow question is tagged with a label identifying its topic or technology. By counting the number of questions related to each technology, you can estimate the popularity of different programming languages.
#
# In this project, you will use data from the Stack Exchange Data Explorer to examine the relative popularity of R compared to other programming languages.
#
# You'll work with a dataset containing one observation per tag per year, including the number of questions for that tag and the total number of questions that year.
#
# `stack_overflow_data.csv`
# |Column|Description|
# |------|-----------|
# |`year`|The year the question was asked (2008-2020)|
# |`tag`|A word or phrase that describes the topic of the question, such as the programming language|
# |`num_questions`|The number of questions with a certain tag in that year|
# |`year_total`|The total number of questions asked in that year|

# %%
# Load necessary packages
library(readr)
library(dplyr)
library(ggplot2)

# %%
# Load the dataset
data <- read_csv("stack_overflow_data.csv")
# Out:
# Rows: 420066 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): tag
# dbl (3): year, num_questions, year_total
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# View the dataset
head(data)
# Out:
#   year tag             num_questions year_total
# 1 2008 treeview        69            168541
# 2 2008 scheduled-tasks 30            168541
# 3 2008 specifications  21            168541
# 4 2008 rendering       35            168541
# 5 2008 http-post        6            168541
# 6 2008 static-assert    1            168541

# %%
unique(data$tag)
# Out:
#     [1] "treeview"
#     [2] "scheduled-tasks"
#     [3] "specifications"
#     [4] "rendering"
#     [5] "http-post"
#     [6] "static-assert"
#     [7] "asp.net-ajax"
#     [8] "collision-detection"
#     [9] "systray"
#    [10] "html-helper"
#    [11] "lookup"
#    [12] "dataflow"
#    [13] "encapsulation"
#    [14] "cag"
#    [15] "kerberos"
#    [16] "simulation"
#    [17] "placeholder"
#    [18] "memory-profiling"
#    [19] "innodb"
#    [20] "applescript"
#    [21] "npapi"
#    [22] "jdialog"
#    [23] "cloning"
#    [24] "uri"
#    [25] "zipinputstream"
#    [26] "safe-mode"
#    [27] "lightbox2"
#    [28] "map"
#    [29] "quartz-composer"
#    [30] "linkbutton"
#    [31] "using"
#    [32] "xstream"
#    [33] "adodb"
#    [34] "svm"
#    [35] "yaws"
#    [36] "axis2"
#    [37] "functor"
#    [38] "signed"
#    [39] "python-dateutil"
#    [40] "thumbnails"
#    [41] "adaptive-compression"
#    [42] "objectoutputstream"
#    [43] "eclipse-3.2"
#    [44] "asdf"
#    [45] "dvd"
#    [46] "nhibernate"
#    [47] "assembly"
#    [48] "methods"
#    [49] "attributes"
#    [50] "pivot"
#    [51] "mnesia"
#    [52] "prediction"
#    [53] "orbited"
#    [54] "database"
#    [55] "velocity"
#    [56] "memcached"
#    [57] "hotfix"
#    [58] "vt100"
#    [59] "accordion"
#    [60] "stored-functions"
#    [61] "tsql"
#    [62] "flash"
#    [63] "authentication"
#    [64] "rmi"
#    [65] "mjpeg"
#    [66] "gentoo"
#    [67] "device"
#    [68] "zope"
#    [69] "modulo"
#    [70] "multiple-resultsets"
#    [71] "reportlab"
#    [72] "device-driver"
#    [73] "windows-vista"
#    [74] "graph-theory"
#    [75] "sdk"
#    [76] "tiger-lines"
#    [77] "fastinfoset"
#    [78] "sinclair"
#    [79] "gnome"
#    [80] "mime"
#    [81] "vector-graphics"
#    [82] "theory"
#    [83] "pseudocode"
#    [84] "jquery-corner"
#    [85] "postsharp"
#    [86] "8-bit"
#    [87] "dojo"
#    [88] "schema"
#    [89] "mxml"
#    [90] "comet"
#    [91] "asp.net-web-api"
#    [92] "datafeed"
#    [93] "wdk"
#    [94] "directed-graph"
#    [95] "greenplum"
#    [96] "upnp"
#    [97] "pagerank"
#    [98] "maven-pdf-plugin"
#    [99] "glob"
#   [100] "nested-datalist"
#   [101] "bigtable"
#   [102] "netbeans6.1"
#   [103] "mailman"
#   [104] "news-ticker"
#   [105] "not-operator"
#   [106] "windows-share"
#   [107] "mmc"
#   [108] "multiplayer"
#   [109] "truststore"
#   [110] "fragment-identifier"
#   [111] "concat"
#   [112] "signing"
#   [113] "filehelpers"
#   [114] "cyclomatic-complexity"
#   [115] "thin-client"
#   [116] "cidr"
#   [117] "biztalk2006r2"
#   [118] "brokenimage"
#   [119] "pivot-table"
#   [120] "ewmh"
#   [121] "handler"
#   [122] "reflector"
#   [123] "mstdc"
#   [124] "hidden-features"
#   [125] "bitwise-operators"
#   [126] "lasso-lang"
#   [127] "mainframe"
#   [128] "clos"
#   [129] "tortoisehg"
#   [130] "eclipse-wtp"
#   [131] "object-slicing"
#   [132] "superscript"
#   [133] "fsm"
#   [134] "tabbed"
#   [135] "xelement"
#   [136] "exists"
#   [137] "fallback"
#   [138] "netadvantage"
#   [139] "adhoc"
#   [140] "oscache"
#   [141] "dct"
#   [142] "quartz-scheduler"
#   [143] "domain-object"
#   [144] "wse3.0"
#   [145] "userid"
#   [146] "tinyxml++"
#   [147] "quoted-identifier"
#   [148] "name-lookup"
#   [149] "richedit"
#   [150] "fluent"
#   [151] "dynamic-programming"
#   [152] "database-abstraction"
#   [153] "pipeline"
#   [154] "imaging"
#   [155] "uielement"
#   [156] "byval"
#   [157] "blog-engine"
#   [158] "bcrypt"
#   [159] "ie-mobile"
#   [160] "video-encoding"
#   [161] "true-type-fonts"
#   [162] "cxf"
#   [163] "grep"
#   [164] "junit"
#   [165] "autoresetevent"
#   [166] "hql"
#   [167] "samba"
#   [168] "sql-update"
#   [169] "spring-ws"
#   [170] "slime"
#   [171] "livesearch"
#   [172] "wsdl2java"
#   [173] "most-vexing-parse"
#   [174] "code-migration"
#   [175] "user-stories"
#   [176] "directx"
#   [177] "identicon"
#   [178] "interpreter"
#   [179] "modem"
#   [180] "performance"
#   [181] "messaging"
#   [182] "selenium-grid"
#   [183] "soap"
#   [184] "internationalization"
#   [185] "web-crawler"
#   [186] "hyper-v"
#   [187] "tkinter"
#   [188] "concrete-syntax-tree"
#   [189] "httpwebrequest"
#   [190] "osc"
#   [191] "swingx"
#   [192] "search"
#   [193] "assemblies"
#   [194] "insert"
#   [195] "cgi"
#   [196] "operators"
#   [197] "distro"
#   [198] "porting"
#   [199] "word-diff"
#   [200] "datetime"
#   [201] "large-files"
#   [202] "ergonomics"
#   [203] "xterm"
#   [204] "parsec"
#   [205] "tryparse"
#   [206] "uuid"
#   [207] "openid"
#   [208] "com+"
#   [209] "click-through"
#   [210] "contains"
#   [211] "movabletype"
#   [212] "noscript"
#   [213] "jar-signing"
#   [214] "remoting"
#   [215] "voicexml"
#   [216] "getopts"
#   [217] "syntax-highlighting"
#   [218] "phpdoc"
#   [219] "visual-assist"
#   [220] "transactions"
#   [221] "jasper-reports"
#   [222] "apache-poi"
#   [223] "flex-lexer"
#   [224] "named-pipes"
#   [225] "bmp"
#   [226] "readability"
#   [227] "normalize"
#   [228] "git-filter-branch"
#   [229] "bcel"
#   [230] "solution-explorer"
#   [231] "cobol"
#   [232] "security"
#   [233] "externals"
#   [234] "filesize"
#   [235] "aspmenu"
#   [236] "jvm-arguments"
#   [237] "bloom-filter"
#   [238] "children"
#   [239] "freetext"
#   [240] "cappuccino"
#   [241] "tcp"
#   [242] "iis-modules"
#   [243] "crashrpt"
#   [244] "office-addins"
#   [245] "sqlconnection"
#   [246] "outer-join"
#   [247] "hide"
#   [248] "z-order"
#   [249] "file-type"
#   [250] "soa"
#   [251] "wireless"
#   [252] "short"
#   [253] "font-size"
#   [254] "swift-mt"
#   [255] "google-visualization"
#   [256] "ajax.net"
#   [257] "variadic-functions"
#   [258] "derived-table"
#   [259] "user-defined-types"
#   [260] "callback"
#   [261] "autocomplete"
#   [262] "branching-and-merging"
#   [263] "dto-mapping"
#   [264] "system-monitoring"
#   [265] "kohana"
#   [266] "diophantine"
#   [267] "cloud"
#   [268] "file"
#   [269] "language-agnostic"
#   [270] "reflection"
#   [271] "thinking-sphinx"
#   [272] "printing"
#   [273] "prompt"
#   [274] "iis-7"
#   [275] "driver"
#   [276] "wincvs"
#   [277] "tiff"
#   [278] "fedora"
#   [279] "absolute-path"
#   [280] "visualsvn-server"
#   [281] "android-emulator"
#   [282] "xmltextreader"
#   [283] "hive"
#   [284] "partial-application"
#   [285] "bulksms"
#   [286] "bare-metal"
#   [287] "artifactory"
#   [288] "init-parameters"
#   [289] "ram-scraping"
#   [290] "svn-checkout"
#   [291] "energy"
#   [292] "dynamically-generated-co"
#   [293] "vssget"
#   [294] "variance"
#   [295] "code-injection"
#   [296] "2phase-commit"
#   [297] "wsacleanup"
#   [298] "crc-cards"
#   [299] "apache-commons-httpclient"
#   [300] "cursor.current"
#   [301] "objdump"
#   [302] "cdma"
#   [303] "serverxmlhttp"
#   [304] "rtml"
#   [305] "regex-negation"
#   [306] "ms-project"
#   [307] "mvcc"
#   [308] "time-complexity"
#   [309] "activescaffold"
#   [310] "evaluation"
#   [311] "spam"
#   [312] "google-base"
#   [313] "terminal-emulator"
#   [314] "alphabetized"
#   [315] "dot-product"
#   [316] "jcl"
#   [317] "vhd"
#   [318] "loose"
#   [319] "mmap"
#   [320] "minidom"
#   [321] "pervasive"
#   [322] "iphone-web-app"
#   [323] "pys60"
#   [324] "sector"
#   [325] "framebuffer"
#   [326] "class-members"
#   [327] "naked-objects"
#   [328] "tab-ordering"
#   [329] "lotusscript"
#   [330] "mask"
#   [331] "gurobi"
#   [332] "instant-message"
#   [333] "apdu"
#   [334] "variable-expansion"
#   [335] "private-key"
#   [336] "nmea"
#   [337] "doc"
#   [338] "lookupfield"
#   [339] "app-store-connect"
#   [340] "erd"
#   [341] "qt-creator"
#   [342] "pixelsense"
#   [343] "compiler-directives"
#   [344] "fieldtype"
#   [345] "dataflow-diagram"
#   [346] "foaf"
#   [347] "hcalendar"
#   [348] "occlusion"
#   [349] "entity-sql"
#   [350] "msf"
#   [351] "in-memory"
#   [352] "console.readkey"
#   [353] "httpunhandledexception"
#   [354] "revert"
#   [355] "fastercsv"
#   [356] "junitperf"
#   [357] "pvcs"
#   [358] "odbc-sql-server-driver"
#   [359] "templatebinding"
#   [360] "componentone"
#   [361] "cookiecontainer"
#   [362] "templating"
#   [363] "python-decimal"
#   [364] "begininvoke"
#   [365] "novell"
#   [366] "syncml"
#   [367] "paperless"
#   [368] "html-agility-pack"
#   [369] "read-write"
#   [370] "heapalloc"
#   [371] "jxbrowser"
#   [372] "securestring"
#   [373] "xml-literals"
#   [374] "email-bounces"
#   [375] "appliance"
#   [376] "cardlayout"
#   [377] "cssedit"
#   [378] "iphelper"
#   [379] "remoteapp"
#   [380] "self-reference"
#   [381] "svnbridge"
#   [382] "unsafe-pointers"
#   [383] "apple-developer"
#   [384] "vbo"
#   [385] "sql-server-migration-assi"
#   [386] "modeladmin"
#   [387] "reinterpret-cast"
#   [388] "olpc"
#   [389] "renaming"
#   [390] "acts-as-tree"
#   [391] "git-remote"
#   [392] "google-feed-api"
#   [393] "peano-numbers"
#   [394] "standardized"
#   [395] "const-method"
#   [396] "boost-regex"
#   [397] "xlwt"
#   [398] "wlan"
#   [399] "ignoreroute"
#   [400] "batching"
#   [401] "openjpa"
#   [402] "date-conversion"
#   [403] "fit-framework"
#   [404] "tor"
#   [405] "jsunit"
#   [406] "lightwindow"
#   [407] "xfdl"
#   [408] "achievements"
#   [409] "lineargradientbrush"
#   [410] "clause"
#   [411] "mysource"
#   [412] "devforce"
#   [413] "unsigned-integer"
#   [414] "cmdb"
#   [415] "btrieve"
#   [416] "stat"
#   [417] "galleria"
#   [418] "file-uri"
#   [419] "cp1252"
#   [420] "repr"
#   [421] "internet-explorer"
#   [422] "ethernet"
#   [423] "handhelddevice"
#   [424] "actionscript"
#   [425] "variables"
#   [426] "ansi-92"
#   [427] "dynamics-gp"
#   [428] "ibatis.net"
#   [429] "mpeg-2"
#   [430] "replace"
#   [431] "compare"
#   [432] "mod-proxy"
#   [433] "wireframe"
#   [434] "firefox-addon"
#   [435] "multi-touch"
#   [436] "fitnesse"
#   [437] "sed"
#   [438] "badge"
#   [439] "ftp-client"
#   [440] "pygame"
#   [441] "hosted"
#   [442] "regex"
#   [443] "image"
#   [444] "utf-16"
#   [445] "stress-testing"
#   [446] "episerver"
#   [447] "pimpl-idiom"
#   [448] "spring-el"
#   [449] "komodo"
#   [450] "cross-posting"
#   [451] "configurationmanager"
#   [452] "formatting"
#   [453] "embedded"
#   [454] "ubuntu"
#   [455] "internals"
#   [456] "cs3"
#   [457] "unique-index"
#   [458] "remember-me"
#   [459] "hierarchical-data"
#   [460] "composite"
#   [461] "equality"
#   [462] "pessimistic"
#   [463] "opengl"
#   [464] "database-installation"
#   [465] "literals"
#   [466] "xpo"
#   [467] "pecl"
#   [468] "uiimage"
#   [469] "symbolic-math"
#   [470] "datetimepicker"
#   [471] "service"
#   [472] "public"
#   [473] "makefile"
#   [474] "oracleexception"
#   [475] "weak-references"
#   [476] "cpu-usage"
#   [477] "http-status-code-404"
#   [478] "env"
#   [479] "scriptaculous"
#   [480] "squid"
#   [481] "multipartform-data"
#   [482] "phpbb3"
#   [483] "buffered"
#   [484] "pgadmin"
#   [485] "htmlpurifier"
#   [486] ".net-assembly"
#   [487] "matrix"
#   [488] "virtual-earth"
#   [489] "filenames"
#   [490] "word-frequency"
#   [491] "matchevaluator"
#   [492] "msmq"
#   [493] "accessibility"
#   [494] "np-complete"
#   [495] "custom-renderer"
#   [496] "dwg"
#   [497] "network-monitoring"
#   [498] "visualize"
#   [499] "python-sphinx"
#   [500] "xampp"
#   [501] "syncfusion"
#   [502] "user-interface"
#   [503] "iptables"
#   [504] "descendant"
#   [505] "kpi"
#   [506] "binary-reproducibility"
#   [507] "equality-operator"
#   [508] "jquery-ui-tabs"
#   [509] "midlet"
#   [510] "mysql-error-1093"
#   [511] "domain-driven-design"
#   [512] "windows-server-2000"
#   [513] "shockwave"
#   [514] "global-variables"
#   [515] "build-server"
#   [516] "avl-tree"
#   [517] "std"
#   [518] "ftpwebrequest"
#   [519] "timer"
#   [520] "pylons"
#   [521] "core-animation"
#   [522] "broadcast"
#   [523] "tlist"
#   [524] "project-planning"
#   [525] "berkeley-db"
#   [526] "account"
#   [527] "listview"
#   [528] "structure"
#   [529] "firebug"
#   [530] "s#arp-architecture"
#   [531] "vfs"
#   [532] "passwordbox"
#   [533] "cross-platform"
#   [534] "arm"
#   [535] "stripes"
#   [536] "strtotime"
#   [537] "capitalize"
#   [538] "swingx-highlighter"
#   [539] "sql-server-2005"
#   [540] "copy"
#   [541] "calendar"
#   [542] "postscript"
#   [543] "destructor"
#   [544] "non-static"
#   [545] "blas"
#   [546] "c++-cli"
#   [547] "jpa"
#   [548] "initialization"
#   [549] "long-integer"
#   [550] "citrix"
#   [551] "preverify"
#   [552] "rapaste"
#   [553] "mysql-real-escape-string"
#   [554] "resetevent"
#   [555] "external-dependencies"
#   [556] "calllog"
#   [557] "dependency-injection"
#   [558] "boolean"
#   [559] "gdb"
#   [560] "this"
#   [561] "exec"
#   [562] "unpack"
#   [563] "clickonce"
#   [564] "gis"
#   [565] "jquery-ui"
#   [566] "svn-export"
#   [567] "voip"
#   [568] "directory-structure"
#   [569] "business-logic-layer"
#   [570] "phpmyadmin"
#   [571] "bots"
#   [572] "waveform"
#   [573] "procmon"
#   [574] "build-automation"
#   [575] "mapi"
#   [576] "pki"
#   [577] "objective-c-runtime"
#   [578] "toolstripitem"
#   [579] "deploying"
#   [580] "dbunit"
#   [581] "yahoo-maps"
#   [582] "paint"
#   [583] "smartcard"
#   [584] "show-hide"
#   [585] "mmapi"
#   [586] "httpexception"
#   [587] "typechecking"
#   [588] "handle"
#   [589] "scopeguard"
#   [590] "joomla1.5"
#   [591] "synthetic"
#   [592] "interactive"
#   [593] "codewarrior"
#   [594] "icefaces"
#   [595] "scrollpane"
#   [596] "nodesets"
#   [597] "crt"
#   [598] "linguistics"
#   [599] "flashcatalyst"
#   [600] "fileopendialog"
#   [601] "dts"
#   [602] "web-deployment-project"
#   [603] "psd"
#   [604] "business-process"
#   [605] "esxi"
#   [606] "null-coalescing-operator"
#   [607] "javasound"
#   [608] "associative-array"
#   [609] "qfe"
#   [610] "argumentnullexception"
#   [611] "cfloop"
#   [612] "y-combinator"
#   [613] "language-detection"
#   [614] "business-connector"
#   [615] "expander"
#   [616] "redmine"
#   [617] "serialversionuid"
#   [618] "dr.watson"
#   [619] "ruby-piston"
#   [620] "bizspark"
#   [621] "form-for"
#   [622] "remobjects"
#   [623] "plugin-architecture"
#   [624] "voicemail"
#   [625] "tracd"
#   [626] "bundle"
#   [627] "idispatch"
#   [628] "carp"
#   [629] "stylus-pen"
#   [630] "uitextfield"
#   [631] "llvm"
#   [632] "webservicetemplate"
#   [633] "proc-open"
#   [634] "styles"
#   [635] "twisted"
#   [636] "ssms"
#   [637] "windows-nt"
#   [638] "href"
#   [639] "rosetta-stone"
#   [640] "signal-processing"
#   [641] "winhttprequest"
#   [642] "persistent"
#   [643] "wxwidgets"
#   [644] "microformats"
#   [645] "semantic-markup"
#   [646] "spring.net"
#   [647] "column-oriented"
#   [648] "classpath"
#   [649] "webserver"
#   [650] "pdf"
#   [651] "error-reporting"
#   [652] "redraw"
#   [653] "black-box"
#   [654] "cewp"
#   [655] "bpl"
#   [656] "mysql"
#   [657] "locking"
#   [658] "erlang"
#   [659] "binary"
#   [660] "biometrics"
#   [661] "networking"
#   [662] "colors"
#   [663] "has-many"
#   [664] "mockrunner"
#   [665] "fade"
#   [666] "custom-errors"
#   [667] "dynamic-cast"
#   [668] "active-directory-group"
#   [669] "parent-child"
#   [670] "non-printable"
#   [671] "declaration"
#   [672] "mx-record"
#   [673] "sap"
#   [674] "xmlnode"
#   [675] "layout"
#   [676] "process-management"
#   [677] "terminal"
#   [678] "visual-sourcesafe"
#   [679] "cursor"
#   [680] "average"
#   [681] "zip"
#   [682] "excel"
#   [683] "powerbuilder"
#   [684] "get"
#   [685] "count"
#   [686] "information-retrieval"
#   [687] "distance"
#   [688] "common-table-expression"
#   [689] "typeconverter"
#   [690] "assignment-operator"
#   [691] "paradigms"
#   [692] "wpf"
#   [693] "stack-overflow"
#   [694] "ram"
#   [695] "gnu-screen"
#   [696] "algorithm"
#   [697] "packet-mangling"
#   [698] "overloading"
#   [699] "conditional-breakpoint"
#   [700] "relaxng"
#   [701] "rotation"
#   [702] "ffmpeg"
#   [703] "visitor"
#   [704] "cycle"
#   [705] "ncover"
#   [706] "httpmodule"
#   [707] "uml"
#   [708] "ltk"
#   [709] "vote"
#   [710] "log4net"
#   [711] "nginx"
#   [712] "startup"
#   [713] "autopostback"
#   [714] "rxtx"
#   [715] "converter"
#   [716] "tix"
#   [717] "static"
#   [718] "allocation"
#   [719] "rhel"
#   [720] "prototype"
#   [721] "copy-constructor"
#   [722] "qsort"
#   [723] "checkout"
#   [724] "python"
#   [725] "html-select"
#   [726] "swt"
#   [727] "query-optimization"
#   [728] "protocol-buffers"
#   [729] "ora-12519"
#   [730] "revisions"
#   [731] "turbo-c++"
#   [732] "scripting-language"
#   [733] "system-views"
#   [734] "floating-point"
#   [735] "maxrequestlength"
#   [736] "extract"
#   [737] "spinner"
#   [738] "table-per-type"
#   [739] "1wire"
#   [740] "animated-gif"
#   [741] "bootstrapper"
#   [742] "moose"
#   [743] "enterprise-manager"
#   [744] "procfs"
#   [745] "onbeforeunload"
#   [746] "logoff"
#   [747] "simulated-annealing"
#   [748] "expression-studio"
#   [749] "alerts"
#   [750] "textile"
#   [751] "autoeventwireup"
#   [752] "jface"
#   [753] "angle"
#   [754] "lgpl"
#   [755] "vtable"
#   [756] "web-optimization"
#   [757] "encryption-asymmetric"
#   [758] "distributed-lock"
#   [759] "dependency-properties"
#   [760] "nt"
#   [761] "scrollviewer"
#   [762] "biztalk-2006"
#   [763] "httpclient"
#   [764] "manpage"
#   [765] "remote-administration"
#   [766] "character"
#   [767] "gif"
#   [768] "prototypal-inheritance"
#   [769] "csproj-user"
#   [770] "portal"
#   [771] "oledbparameter"
#   [772] "side-by-side"
#   [773] "dds-format"
#   [774] "pgp"
#   [775] "renderer"
#   [776] "program-transformation"
#   [777] "quotations"
#   [778] "modular"
#   [779] "urlclassloader"
#   [780] "fsfs"
#   [781] "matisse"
#   [782] "version-control-migration"
#   [783] "open-uri"
#   [784] "language-binding"
#   [785] "filter-input"
#   [786] "desktop-background"
#   [787] "ultracombo"
#   [788] "nvarchar"
#   [789] "gantt-chart"
#   [790] "cell"
#   [791] "oop"
#   [792] "mongrel"
#   [793] "reference"
#   [794] "postal-code"
#   [795] "publishing"
#   [796] "manuals"
#   [797] "title"
#   [798] "comments"
#   [799] "mysql-workbench"
#   [800] "ksoap"
#   [801] "crc"
#   [802] "excel-2002"
#   [803] "streaming"
#   [804] "command"
#   [805] "ipv6"
#   [806] "dynamic-compilation"
#   [807] "soaphttpclientprotocol"
#   [808] "antrunner"
#   [809] "jcarousel"
#   [810] "desktop-application"
#   [811] "google-reader"
#   [812] "contextmenu"
#   [813] "data-integration"
#   [814] "off-screen"
#   [815] "ocaml"
#   [816] "file-format"
#   [817] "upsert"
#   [818] "annotate"
#   [819] "application-state"
#   [820] "multidimensional-array"
#   [821] "syntax"
#   [822] "projects"
#   [823] "inverse-match"
#   [824] "name-length"
#   [825] "action"
#   [826] "string-search"
#   [827] "bouncedemail"
#   [828] "digg"
#   [829] "windowsformshost"
#   [830] "mpi"
#   [831] "progress-bar"
#   [832] "icalendar"
#   [833] "maven-2"
#   [834] "onlinebanking"
#   [835] "git-archive"
#   [836] "auditing"
#   [837] "jquery-ui-sortable"
#   [838] "blazeds"
#   [839] "clearcase"
#   [840] "trace"
#   [841] "twain"
#   [842] "controls"
#   [843] "solaris"
#   [844] "jar"
#   [845] "sitecore"
#   [846] "cpu"
#   [847] "connectivity"
#   [848] "spring-mvc"
#   [849] "friendly-url"
#   [850] "punycode"
#   [851] "xmlbeans"
#   [852] "fiddler"
#   [853] "app-id"
#   [854] "war"
#   [855] "video"
#   [856] "rhino-mocks"
#   [857] "webrequest"
#   [858] "ipc"
#   [859] "ghostdoc"
#   [860] "detach"
#   [861] "currying"
#   [862] "puremvc"
#   [863] "testing"
#   [864] "middleware"
#   [865] "transparency"
#   [866] "mp3"
#   [867] "watin"
#   [868] "report"
#   [869] "cruisecontrol"
#   [870] "label"
#   [871] "subdomain"
#   [872] "foreign-key-relationship"
#   [873] "epoll"
#   [874] "thread-priority"
#   [875] "wid"
#   [876] "seam"
#   [877] "servicepacks"
#   [878] "shortcut"
#   [879] "avatars"
#   [880] "bug-reporting"
#   [881] "redirect"
#   [882] "lotus-domino"
#   [883] "cryptography"
#   [884] "predicate"
#   [885] "auto-ptr"
#   [886] "hidden-markov-models"
#   [887] "ajaxcontroltoolkit"
#   [888] "listbox"
#   [889] "hashtable"
#   [890] "dunit"
#   [891] "os-dependent"
#   [892] "underline"
#   [893] "circuit"
#   [894] "gridworld"
#   [895] "objective-j"
#   [896] "rijndaelmanaged"
#   [897] "ice"
#   [898] "abstract"
#   [899] "application-start"
#   [900] "email-client"
#   [901] "unsigned"
#   [902] "red5"
#   [903] "xmlnodelist"
#   [904] "ole-automation"
#   [905] "custom-attributes"
#   [906] "isapi"
#   [907] "itemeditor"
#   [908] "argumentexception"
#   [909] "screen"
#   [910] "bitmapsource"
#   [911] "mechanicalturk"
#   [912] "rpath"
#   [913] "jsch"
#   [914] "nexus"
#   [915] "bankers-rounding"
#   [916] "jaxp"
#   [917] "jersey"
#   [918] "convention"
#   [919] "eclipselink"
#   [920] "community-server"
#   [921] "qtreeview"
#   [922] "background-color"
#   [923] "countdownlatch"
#   [924] "dst"
#   [925] "trim"
#   [926] "ssrs-2012"
#   [927] "great-circle"
#   [928] "gd"
#   [929] "system.drawing"
#   [930] "coalesce"
#   [931] "mark-of-the-web"
#   [932] "cart"
#   [933] "distributed-database"
#   [934] "http-status-code-403"
#   [935] "calendarextender"
#   [936] "open-closed-principle"
#   [937] "gnu-toolchain"
#   [938] "conceptual"
#   [939] "autolayout"
#   [940] "spatial"
#   [941] "access-denied"
#   [942] "authenticode"
#   [943] "junit4"
#   [944] "sample"
#   [945] "ntp"
#   [946] "vix"
#   [947] "reportviewer"
#   [948] "aquamacs"
#   [949] "subtree"
#   [950] "ruby"
#   [951] "quicktime"
#   [952] "timtowtdi"
#   [953] "post-build-event"
#   [954] "nasm"
#   [955] "call-graph"
#   [956] "business-intelligence"
#   [957] "validation"
#   [958] "interface-design"
#   [959] "expression-blend-2"
#   [960] "linklabel"
#   [961] ".net-3.5"
#   [962] "plugins"
#   [963] "preferences"
#   [964] "mercurial-queue"
#   [965] "tframe"
#   [966] "cakephp-1.2"
#   [967] "fstream"
#   [968] "binary-data"
#   [969] "pyodbc"
#   [970] "unmanaged"
#   [971] "read-committed-snapshot"
#   [972] "ncr"
#   [973] "server-configuration"
#   [974] "ankhsvn"
#   [975] "google-oauth"
#   [976] "monitor"
#   [977] "formulas"
#   [978] "castle"
#   [979] "default-constructor"
#   [980] "observablecollection"
#   [981] "activemq"
#   [982] "intersection"
#   [983] "photography"
#   [984] "sql-server-mobile"
#   [985] "grouping"
#   [986] "idataerrorinfo"
#   [987] "generic-type-argument"
#   [988] "text"
#   [989] "richtextbox"
#   [990] "castor"
#   [991] "friend"
#   [992] "mesh"
#   [993] "lazy-registration"
#   [994] "terminology"
#   [995] "positioning"
#   [996] "activestate"
#   [997] "xcopy"
#   [998] "eigenvalue"
#   [999] "utf-8"
#  [1000] "mfc-feature-pack"
#  [1001] "offline"
#  [1002] "find"
#  [1003] "open-source"
#  [1004] "buffer-overflow"
#  [1005] "autotools"
#  [1006] "lossy-compression"
#  [1007] "rman"
#  [1008] "lds"
#  [1009] "esri"
#  [1010] "lighttpd"
#  [1011] "winhttp"
#  [1012] "implicit"
#  [1013] "uidl"
#  [1014] "fogbugz"
#  [1015] "outlook"
#  [1016] "flush"
#  [1017] "machine-learning"
#  [1018] "relocation"
#  [1019] "firebird"
#  [1020] "jdbc"
#  [1021] "clojure"
#  [1022] "code-access-security"
#  [1023] "jslint"
#  [1024] "curl"
#  [1025] "m4a"
#  [1026] "effects"
#  [1027] "sass"
#  [1028] "screenshot"
#  [1029] "ldf"
#  [1030] "ntvdm.exe"
#  [1031] "key"
#  [1032] "tarfile"
#  [1033] "processor"
#  [1034] "itext"
#  [1035] "windows-explorer"
#  [1036] "impersonation"
#  [1037] "json-serialization"
#  [1038] "apple-ii"
#  [1039] "heap"
#  [1040] "adobe"
#  [1041] "stream"
#  [1042] "tdd"
#  [1043] "jquery-selectors"
# ...
# [59298] "gatsby-plugin-mdx"
# [59299] "surface-duo"
# [59300] "get-cmiclass"
# [59301] "java-record"
# [59302] "flag-secure"
# [59303] "kotlin-coroutine-channel"
# [59304] "tuf"
# [59305] "tom.h"
# [59306] "watchos-7"
# [59307] "nova-media-library"
# [59308] "asp-net-core"
# [59309] "arangodb-java"
# [59310] "apache-commons-text"
# [59311] "chart.js3"
# [59312] "grunt-terser"
# [59313] "go-testing"
# [59314] "sts"
# [59315] "spokestack"
# [59316] "type-mapping"
# [59317] "par2"
# [59318] "azure-functions-docker"
# [59319] "concordance-index"
# [59320] "android-gradient-drawable"
# [59321] "resharper-2019"
# [59322] "epel-testing"
# [59323] "acme.sh"
# [59324] "yarnpkg-pnp"
# [59325] "pg-wrapper"
# [59326] "edgesdk"
# [59327] "webhid"
# [59328] "background-refresh"
# [59329] "unregisteredtypeexception"
# [59330] "clara-rule-engine"
# [59331] "modernizer-maven-plugin"
# [59332] "fxgl"
# [59333] "soapcore"
# [59334] "moleculer-web"
# [59335] "weld-junit4"
# [59336] "microsoft-file-explorer"
# [59337] "solidus-stripe"
# [59338] "git-hunk"
# [59339] "alleyinteractive"
# [59340] "primeng-menu"
# [59341] "swift5.3"
# [59342] "custom-redirects"
# [59343] "use-ref"
# [59344] "ibm-cloud-code-engine"
# [59345] "ngtemplateoutlet"
# [59346] "jetson-xavier"
# [59347] "ko"
# [59348] "flutter-padding"
# [59349] "automapper-10"
# [59350] "ta4j"
# [59351] "indeterminate-progress-bar"
# [59352] "trimble-maps"
# [59353] "azure-static-website-routing"
# [59354] "ionos"
# [59355] "jsonify"
# [59356] "react-easy-state"
# [59357] "eiffel-studio-19.12"
# [59358] "vue-worker"
# [59359] "swiftui-previews"
# [59360] "winlink"
# [59361] "ios13.7"
# [59362] "pareto-optimality"
# [59363] "ngx-doc-viewer"
# [59364] "cuda-driver"
# [59365] "single-spa"
# [59366] "position-sticky"
# [59367] "documentgroup"
# [59368] "krazo"
# [59369] "third-party-cookies"
# [59370] "uirouter"
# [59371] "imap-server"
# [59372] "gridattachmentcolumn"
# [59373] "eta"
# [59374] "seahorn"
# [59375] "frequency-table"
# [59376] "flatbutton"
# [59377] "muipickersutilsprovider"
# [59378] "vue2leaflet"
# [59379] "google-business"
# [59380] "applehealth"
# [59381] "urlqueryitem"
# [59382] "spring-boot-starter-security"
# [59383] "dask-to-sql"
# [59384] "toolbaritemgroup"
# [59385] "nested-stack"
# [59386] "autosizing"
# [59387] "jina"
# [59388] "java-process-runtime"
# [59389] "dotnet-watch"
# [59390] "redfish"
# [59391] "direct-initialization"
# [59392] "sloc"
# [59393] "cxxopts"
# [59394] "nsgridview"
# [59395] "scrollcontroller"
# [59396] "oss-licenses-plugin"
# [59397] "flask-restx"
# [59398] "shopifysharp"
# [59399] "bayesian-deep-learning"
# [59400] "vaadin-on-kotlin"
# [59401] "wildfly-camel"
# [59402] "apollo-datasource"
# [59403] "chartjs-node-canvas"
# [59404] "nfcreadersession"
# [59405] "arrayofstruct"
# [59406] "redux-selector"
# [59407] "django-3.1"
# [59408] "flutter-in-app-purchase"
# [59409] "nested-for-loop"
# [59410] "cluster-manager"
# [59411] "mongodb-schema"
# [59412] "fabletools"
# [59413] "eslint-config-vue"
# [59414] "cdk8s"
# [59415] "iazureclientfactory"
# [59416] "wcfcoremtomencoder"
# [59417] "d3-transition"
# [59418] "horizontal-card"
# [59419] "geofence"
# [59420] "expo-camera"
# [59421] "azure-private-dns-zone"
# [59422] "deepnote"
# [59423] "reality-converter"
# [59424] "django-photologue"
# [59425] "google-one-tap"
# [59426] "kibana-plugin"
# [59427] "ns-3.30"
# [59428] "serf"
# [59429] "ssrs-2019"
# [59430] "ia16-gcc"
# [59431] "divi"
# [59432] "htmlfromxamlconverter"
# [59433] "punctuator"
# [59434] "ml5.js"
# [59435] "weaver"
# [59436] "json-remove"
# [59437] "cypress-cucumber-preprocessor"
# [59438] "anyproxy"
# [59439] "color-gradient"
# [59440] "react.net"
# [59441] "react-native-braintree-dropin-ui"
# [59442] "execution-api"
# [59443] "linqpad5"
# [59444] "dpmi"
# [59445] "task-definition"
# [59446] "msgmerge"
# [59447] "azureadgraph-deprecation"
# [59448] "sysrepo"
# [59449] "expo-notifications"
# [59450] "swiftpm"
# [59451] "pos.net"
# [59452] "keras-tuner"
# [59453] "elasticpress"
# [59454] "vim-folding"
# [59455] "largeobject"
# [59456] "jdk-desugaring"
# [59457] "adal-deprecation"
# [59458] "react-effects"
# [59459] "trailing-lambda"
# [59460] "dotnet-build"
# [59461] "svg2rlg"
# [59462] "dse"
# [59463] "cppwinrt"
# [59464] "obs-studio"
# [59465] "microstack"
# [59466] "orjson"
# [59467] "imagecreatetruecolor"
# [59468] "tasty"
# [59469] "graphql-modules"
# [59470] "pymks"
# [59471] "myst"
# [59472] "overrideredirected-window"
# [59473] "nvd"
# [59474] "testcontainers-keycloak"
# [59475] "jenkins-global-library"
# [59476] "jhipster-gateway"
# [59477] "multipartfile"
# [59478] "primefaces-8.0"
# [59479] "stanford-stanza"
# [59480] "postgresql-13"
# [59481] "ondisappearing"
# [59482] "dcdevice"
# [59483] "netcdf-java"
# [59484] "update-by-query"
# [59485] "webgpu"
# [59486] "qt5.13"
# [59487] "azure-ad-b2c-custom-policy"
# [59488] "horos"
# [59489] "spring-boot-migration-1.5.x-2.1.x"
# [59490] "cybersecurity"
# [59491] "efcorejsonvalueconverter"
# [59492] "ipld"
# [59493] "ubi"
# [59494] "offsetdatetime"
# [59495] "vip"
# [59496] "icelink"
# [59497] "react-native-iap"
# [59498] "jandex"
# [59499] "cosmosclient"
# [59500] "graph-data-science"
# [59501] "express-openapi-validator"
# [59502] "ngx-swiper-wrapper"
# [59503] "cusignal"
# [59504] "azsclient"
# [59505] "lusca"
# [59506] "simulink-library"
# [59507] "angular-cli-v9"
# [59508] "react-app-rewired"
# [59509] "nonlinear-equation"
# [59510] "quarkus-rest-client"
# [59511] "react-bootstrap-nav"
# [59512] "chartjs-plugin-annotation"
# [59513] "sql-server-azure"
# [59514] "privateid"
# [59515] "deck-swiper"
# [59516] "pose-detection"
# [59517] "trivially-copyable"
# [59518] "electron-util"
# [59519] "dynamodb-mapper"
# [59520] "deckswiper"
# [59521] "material-components-cards"
# [59522] "aws-code-deploy-appspec"
# [59523] "coachmark"
# [59524] "action-process-text"
# [59525] "ogl"
# [59526] "windowgroup"
# [59527] "java-vertx-web"
# [59528] "goreplay"
# [59529] "trailing-whitespace"
# [59530] "pg-config"
# [59531] "glooey"
# [59532] "vim-lsp"
# [59533] "swiper.js"
# [59534] "typescript-analyzer"
# [59535] "flutter-bottomnavigation"
# [59536] "robotframwork-whitelibrary"
# [59537] "wildwebdeveloper"
# [59538] "activity-scenario"
# [59539] "atzmus"
# [59540] "chronounit"
# [59541] "json-api-response-converter"
# [59542] "highcharts-gantt"
# [59543] "nativescript-playground"
# [59544] "vue-data"
# [59545] "exclamation-mark"
# [59546] "google-sdm-api"
# [59547] "no-unique-address"
# [59548] "mariadb4j"
# [59549] "dart-angel"
# [59550] "pipeline-options"
# [59551] "cableready"
# [59552] "sqlbulktools"
# [59553] "stable-baselines"
# [59554] "blockoperation"
# [59555] "tensorflow1.15"
# [59556] "native-testing-library"
# [59557] "nodemcu-build"
# [59558] "react-infinite-scroll"
# [59559] "apache-beam-kafkaio"
# [59560] "webpack-mix"
# [59561] "gnu-date"
# [59562] "pdfmerger"
# [59563] "jsonfield"
# [59564] "quarkus-qute"
# [59565] "fa-svelte"
# [59566] "wc-admin"
# [59567] "vitess.io"
# [59568] "gtk2combobox"
# [59569] "gogo"
# [59570] "indicative"
# [59571] "akka-discovery"
# [59572] "flask-table"
# [59573] "heremaps-android-sdk"
# [59574] "lock-guard"
# [59575] "deno-postgres"
# [59576] "help-tab"
# [59577] "rxe"
# [59578] "d2l"
# [59579] "grafana-plugin"
# [59580] "ninja-ide"
# [59581] "oci-typescript-sdk"
# [59582] "splunk-hec"
# [59583] "react-native-modalize"
# [59584] "zerocrossing"
# [59585] "pumba"
# [59586] "cfif"
# [59587] "maven-repository"
# [59588] "constrained-auto"
# [59589] "git-duet"
# [59590] "awesometable"
# [59591] "keyboard-focus"
# [59592] "needle"
# [59593] "mailtrap"
# [59594] "bottom"
# [59595] "deno-sql"
# [59596] "compiler-definitions"
# [59597] "vue-range-slider"
# [59598] "fetch-mock-jest"
# [59599] "node-worker-threads"
# [59600] "snapshot-testing"
# [59601] "text-emphasis"
# [59602] "rstudioapi"
# [59603] "fortran-non-overridable"
# [59604] "sonarqube-7.9"
# [59605] "leaflet.heat"
# [59606] "exq"
# [59607] "java-resources"
# [59608] "opencoarrays"
# [59609] "debian-control"
# [59610] "jquery-selectable"
# [59611] "feast"
# [59612] "read-access"
# [59613] "ibm-cloud-speech"
# [59614] "printooth"
# [59615] "google-cla"
# [59616] "electron-webpack"
# [59617] "vuejs-routing"
# [59618] "react-codemod"
# [59619] "office365-rest-client"
# [59620] "intrange"
# [59621] "chargebee"
# [59622] "mosaic-decisions"
# [59623] "reactable"
# [59624] "facenet"
# [59625] "spring-webmvc.fn"
# [59626] "gcloudignore"
# [59627] "pyvis"
# [59628] "azure-http-trigger"
# [59629] "micronaut-openapi"
# [59630] "maven-jib"
# [59631] "testinghelpers"
# [59632] "elogii"
# [59633] "05ab1e"
# [59634] "standardx"
# [59635] "node-sspi"
# [59636] "xplane"
# [59637] "flutter-form-builder"
# [59638] "westwddlogic"
# [59639] "libftdi"
# [59640] "cypher-query"
# [59641] "restrict-content-pro"
# [59642] "web-application-security"
# [59643] "scrapyd-deploy"
# [59644] "gcr.io"
# [59645] "timageviewer"

# %%
# Corrected code
# Assuming your data is in a data frame called 'df'
library(dplyr)

r_2020 <- data %>%
  select(year, tag, num_questions, year_total)%>%
  filter(tag == "r", year == 2020) %>%
  mutate(percentage = num_questions / year_total * 100)

# %%
print(r_2020)
# Out:
# # A tibble: 1 × 5
#    year tag   num_questions year_total percentage
#   <dbl> <chr>         <dbl>      <dbl>      <dbl>
# 1  2020 r             52662    5452545      0.966

# %%
highest_tags <- data %>% filter(year >= 2015 & year <= 2020) %>% group_by(tag) %>%summarise(total_questions= sum(num_questions)) %>% slice_max(total_questions, n=5)

# %%
print(highest_tags)
# Out:
# # A tibble: 5 × 2
#   tag        total_questions
#   <chr>                <dbl>
# 1 javascript         1373634
# 2 python             1187838
# 3 java                982747
# 4 android             737330
# 5 c#                  730045
